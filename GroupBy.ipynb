# %%
import pandas as pd

# %%
vendas = pd.DataFrame({'Produto':['Chocolate','Banana','Chocolate','Banana'],
                       'Quantidade':[200,80,200,80],
                       'Preço':[3,0.5,3,0.5]})
vendas
# Out:
#      Produto  Quantidade  Preço
# 0  Chocolate         200    3.0
# 1     Banana          80    0.5
# 2  Chocolate         200    3.0
# 3     Banana          80    0.5

# %%
grupoProduto = vendas.groupby('Produto')

# %%
grupoProduto.sum()
# Out:
#            Quantidade  Preço
# Produto
# Banana            160    1.0
# Chocolate         400    6.0

# %%
grupoProduto.describe()
# Out:
#           Quantidade                                                Preço  \
#                count   mean  std    min    25%    50%    75%    max count
# Produto
# Banana           2.0   80.0  0.0   80.0   80.0   80.0   80.0   80.0   2.0
# Chocolate        2.0  200.0  0.0  200.0  200.0  200.0  200.0  200.0   2.0
#
#
#           mean  std  min  25%  50%  75%  max
# Produto
# Banana     0.5  0.0  0.5  0.5  0.5  0.5  0.5
# Chocolate  3.0  0.0  3.0  3.0  3.0  3.0  3.0
